# %%
import pandas as pd
data = pd.read_csv("survey_results_public.csv")
data
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
data.shape
# Out:
# (89184, 84)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
data.head(20)
# Out:
#     ResponseId     Q120                                         MainBranch  \
# 0            1  I agree                                      None of these
# 1            2  I agree                     I am a developer by profession
# 2            3  I agree                     I am a developer by profession
# 3            4  I agree                     I am a developer by profession
# 4            5  I agree                     I am a developer by profession
# 5            6  I agree                     I am a developer by profession
# 6            7  I agree                     I am a developer by profession
# 7            8  I agree                     I am a developer by profession
# 8            9  I agree  I am not primarily a developer, but I write co...
# 9           10  I agree                     I am a developer by profession
# 10          11  I agree                     I am a developer by profession
# ...

# %%
data.tail(20)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89164       89165  I agree  I am a developer by profession
# 89165       89166  I agree  I am a developer by profession
# 89166       89167  I agree  I am a developer by profession
# 89167       89168  I agree  I am a developer by profession
# 89168       89169  I agree  I am a developer by profession
# 89169       89170  I agree  I am a developer by profession
# 89170       89171  I agree  I am a developer by profession
# 89171       89172  I agree  I am a developer by profession
# 89172       89173  I agree  I am a developer by profession
# 89173       89174  I agree  I am a developer by profession
# 89174       89175  I agree  I am a developer by profession
# 89175       89176  I agree  I am a developer by profession
# 89176       89177  I agree  I am a developer by profession
# 89177       89178  I agree  I am a developer by profession
# 89178       89179  I agree  I am a developer by profession
# ...

# %%
pd.set_option('display.max_columns',85)
data
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
data['Employment']
# Out:
# 0                                                      NaN
# 1                                      Employed, full-time
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4        Employed, full-time;Independent contractor, fr...
#                                ...
# 89179    Employed, full-time;Independent contractor, fr...
# 89180               Student, full-time;Employed, part-time
# 89181                                  I prefer not to say
# 89182               Employed, part-time;Student, part-time
# 89183                                  Employed, full-time
# Name: Employment, Length: 89184, dtype: object

# %%
data.Employment.value_counts()
# Out:
# Employed, full-time                                                                                                                                                                                             53748
# Student, full-time                                                                                                                                                                                               7430
# Independent contractor, freelancer, or self-employed                                                                                                                                                             7076
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                         4354
# ...

# %%
data['OpSysProfessional use'].value_counts()
# Out:
# Windows                                                                                                     15943
# MacOS                                                                                                       12928
# Ubuntu                                                                                                       5201
# Windows;Windows Subsystem for Linux (WSL)                                                                    3934
# Ubuntu;Windows                                                                                               2795
#                                                                                                             ...
# Debian;iOS;iPadOS;MacOS;Red Hat;Windows                                                                         1
# BSD;Other Linux-based;Red Hat                                                                                   1
# ...

# %%
data.Employment[89182]
# Out:
# 'Employed, part-time;Student, part-time'

# %%
data['DevType'].value_counts()
# Out:
# Developer, full-stack                            25735
# Developer, back-end                              13745
# Developer, front-end                              5071
# Developer, desktop or enterprise applications     3904
# Other (please specify):                           3080
# Developer, mobile                                 2597
# Engineering manager                               2033
# Student                                           1996
# Developer, embedded applications or devices       1845
# Data scientist or machine learning specialist     1588
# DevOps specialist                                 1387
# Academic researcher                               1354
# Research & Development role                       1353
# Senior Executive (C-Suite, VP, etc.)              1332
# Engineer, data                                    1248
# Cloud infrastructure engineer                     1036
# Developer, game or graphics                        866
# ...

# %%
macos_users = data[data['OpSysProfessional use']=="MacOS"]

# %%
macos_users
# Out:
#        ResponseId     Q120                      MainBranch  \
# 5               6  I agree  I am a developer by profession
# 6               7  I agree  I am a developer by profession
# 16             17  I agree  I am a developer by profession
# 17             18  I agree  I am a developer by profession
# 20             21  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89134       89135  I agree     I code primarily as a hobby
# 89141       89142  I agree  I am a developer by profession
# 89153       89154  I agree  I am a developer by profession
# 89155       89156  I agree  I am a developer by profession
# 89156       89157  I agree  I am a developer by profession
#
#                       Age           Employment  \
# 5         35-44 years old  Employed, full-time
# 6         35-44 years old  Employed, full-time
# 16        35-44 years old  Employed, full-time
# 17        25-34 years old  Employed, full-time
# ...

# %%
data['Country'].value_counts()
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: Country, Length: 185, dtype: int64

# %%
usa_developers=data[data['Country']=="United States of America"]

# %%
usa_developers
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 1               2  I agree                     I am a developer by profession
# 2               3  I agree                     I am a developer by profession
# 3               4  I agree                     I am a developer by profession
# 6               7  I agree                     I am a developer by profession
# 7               8  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89150       89151  I agree  I used to be a developer by profession, but no...
# 89154       89155  I agree                     I am a developer by profession
# 89156       89157  I agree                     I am a developer by profession
# 89175       89176  I agree                     I am a developer by profession
# 89178       89179  I agree                     I am a developer by profession
#
# ...

# %%
indian_developers=data[data['Country']=="India"]

# %%
indian_developers
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# 89121       89122  I agree  I am not primarily a developer, but I write co...
# 89164       89165  I agree                     I am a developer by profession
# 89165       89166  I agree                     I am a developer by profession
# 89167       89168  I agree                     I am a developer by profession
#
# ...

# %%
usa_developers['Age'].value_counts()
# Out:
# 25-34 years old       6283
# 35-44 years old       4855
# 18-24 years old       2468
# 45-54 years old       2277
# 55-64 years old       1238
# Under 18 years old     867
# 65 years or older      529
# Prefer not to say      130
# Name: Age, dtype: int64

# %%
indian_developers['Age'].value_counts()
# Out:
# 18-24 years old       2296
# 25-34 years old       2289
# 35-44 years old        512
# Under 18 years old     378
# 45-54 years old        107
# 55-64 years old         20
# Prefer not to say       19
# 65 years or older        4
# Name: Age, dtype: int64

# %%
data[(data['Country']=="India") & (data['CodingActivities']=="Hobby") & (data['Employment']=="Employed, full-time")]
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 78             79  I agree  I am a developer by profession  18-24 years old
# 82             83  I agree  I am a developer by profession  25-34 years old
# 172           173  I agree  I am a developer by profession  18-24 years old
# 397           398  I agree  I am a developer by profession  18-24 years old
# 404           405  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 87460       87461  I agree  I am a developer by profession  25-34 years old
# 87486       87487  I agree  I am a developer by profession  18-24 years old
# 87526       87527  I agree  I am a developer by profession  35-44 years old
# 87724       87725  I agree  I am a developer by profession  18-24 years old
# 88037       88038  I agree  I am a developer by profession  18-24 years old
#
# ...

# %%
filter = (data['Country']=='India') & (data["RemoteWork"]=="Remote") & (data['ConvertedCompYearly']>10000)
data[filter]
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 127           128  I agree  I am a developer by profession  25-34 years old
# 177           178  I agree  I am a developer by profession  35-44 years old
# 209           210  I agree  I am a developer by profession  18-24 years old
# 377           378  I agree  I am a developer by profession  35-44 years old
# 380           381  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 88955       88956  I agree  I am a developer by profession  25-34 years old
# 89034       89035  I agree  I am a developer by profession  25-34 years old
# 89084       89085  I agree  I am a developer by profession  25-34 years old
# 89105       89106  I agree  I am a developer by profession  18-24 years old
# 89167       89168  I agree  I am a developer by profession  18-24 years old
#
#                 Employment RemoteWork  \
# ...

# %%
data[filter].LanguageHaveWorkedWith.value_counts()
# Out:
# HTML/CSS;JavaScript;TypeScript                                             31
# Python                                                                     12
# JavaScript;TypeScript                                                      12
# JavaScript                                                                  9
# HTML/CSS;JavaScript                                                         7
#                                                                            ..
# Go;HTML/CSS;JavaScript;Python;SQL;TypeScript                                1
# Bash/Shell (all shells);Go;HTML/CSS;JavaScript;TypeScript                   1
# Go;JavaScript;PHP;TypeScript                                                1
# Bash/Shell (all shells);C++;Dart;HTML/CSS;Java;JavaScript;Kotlin;Python     1
# Dart;HTML/CSS;JavaScript;TypeScript                                         1
# Name: LanguageHaveWorkedWith, Length: 364, dtype: int64

# %%
data[filter].LearnCode.value_counts()
# Out:
# Online Courses or Certification;Other online resources (e.g., videos, blogs, forum)                                                                                                                                         49
# Other online resources (e.g., videos, blogs, forum)                                                                                                                                                                         40
# Books / Physical media;Online Courses or Certification;Other online resources (e.g., videos, blogs, forum)                                                                                                                  26
# Online Courses or Certification;On the job training;Other online resources (e.g., videos, blogs, forum)                                                                                                                     25
# ...

# %%
data[filter].WebframeHaveWorkedWith.value_counts()
# Out:
# React                                                             16
# Spring Boot                                                       14
# FastAPI;Flask                                                     10
# Node.js;React                                                     10
# Express;Node.js;React                                             10
#                                                                   ..
# Django;Express;FastAPI;Flask;Next.js;Node.js;React                 1
# Express;Fastify;Node.js;React                                      1
# Django;Express;FastAPI;Flask;Next.js;Node.js;React;Spring Boot     1
# Angular;Flask;Node.js;React;Spring Boot                            1
# Express;Node.js;React;Svelte                                       1
# Name: WebframeHaveWorkedWith, Length: 303, dtype: int64

# %%
data
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
#setting our own index
data = pd.read_csv("survey_results_public.csv",index_col='ResponseId')
data
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
survey=pd.read_csv("survey_results_schema.csv",index_col='qname')
survey
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# Q310         QID310  <div><span style="font-size:19px;"><strong>You...
# Q120         QID312
# S1             QID1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# Knowledge_7  QID289  Waiting on answers to questions often causes i...
# Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# Frequency_1  QID290  Needing help from people outside of your immed...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# ...

# %%
survey.loc['Knowledge_1']
# Out:
# qid                                                      QID289
# question      I have interactions with people outside of my ...
# force_resp                                                  NaN
# type                                                         MC
# selector                                                   MAVR
# Name: Knowledge_1, dtype: object

# %%
survey.loc['Knowledge_1'].question
# Out:
# 'I have interactions with people outside of my immediate team.'

# %%
#data[data['Country']=="United States of America"]
data.query('Country == "United States of America"')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 2           I agree                     I am a developer by profession
# 3           I agree                     I am a developer by profession
# 4           I agree                     I am a developer by profession
# 7           I agree                     I am a developer by profession
# 8           I agree                     I am a developer by profession
# ...             ...                                                ...
# 89151       I agree  I used to be a developer by profession, but no...
# 89155       I agree                     I am a developer by profession
# 89157       I agree                     I am a developer by profession
# 89176       I agree                     I am a developer by profession
# 89179       I agree                     I am a developer by profession
#
#                         Age           Employment  \
# ResponseId
# ...

# %%
data['YearsCodePro']=pd.to_numeric(data['YearsCodePro'],errors='coerce')
sample_devs = data.query('ConvertedCompYearly>100000 & Country=="India" & RemoteWork=="Remote" & YearsCodePro<12 ')

# %%
sample_devs['LanguageHaveWorkedWith'].value_counts()
# Out:
# C++;HTML/CSS;JavaScript;Python                    1
# C++;Go;Java;JavaScript;Python                     1
# JavaScript;TypeScript                             1
# HTML/CSS;Java;JavaScript;Python;SQL;TypeScript    1
# HTML/CSS;Java;JavaScript                          1
# HTML/CSS;JavaScript;TypeScript                    1
# Name: LanguageHaveWorkedWith, dtype: int64

# %%
max_value = data['ConvertedCompYearly'].max()

# %%
second_highest = data[data['ConvertedCompYearly']<max_value]['ConvertedCompYearly'].max()

# %%
second_highest
# Out:
# 73607918.0

# %%
#second_highest.sort_values(ascending=False).head(20)

# %%
data['ConvertedCompYearly'].quantile(0.999)
max_salary = data['ConvertedCompYearly'].quantile(0.999)

# %%
data[data['ConvertedCompYearly'] > max_salary]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 771         I agree                     I am a developer by profession
# 5905        I agree                     I am a developer by profession
# 7487        I agree                     I am a developer by profession
# 7995        I agree                     I am a developer by profession
# 9394        I agree                     I am a developer by profession
# 10519       I agree                     I am a developer by profession
# 14592       I agree                     I am a developer by profession
# 16082       I agree                     I am a developer by profession
# 16632       I agree                     I am a developer by profession
# 16667       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 20783       I agree                     I am a developer by profession
# ...

# %%
data = data[data['ConvertedCompYearly'] > max_salary]

# %%
data['ConvertedCompYearly'].max()
# Out:
# 74351432.0

# %%
data[data['ConvertedCompYearly'] == data['ConvertedCompYearly'].max()]
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 53269       I agree  I am a developer by profession  18-24 years old
#
#                                                    Employment  \
# ResponseId
# 53269       Independent contractor, freelancer, or self-em...
#
#                                       RemoteWork  \
# ResponseId
# 53269       Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 53269       Hobby;Contribute to open-source projects;Boots...
#
#                                                    EdLevel  \
# ResponseId
# 53269       Professional degree (JD, MD, Ph.D, Ed.D, etc.)
#
#                                                     LearnCode  \
# ResponseId
# 53269       Friend or family member;Online Courses or Cert...
#
#                                               LearnCodeOnline  \
# ResponseId
# ...

# %%
data['ConvertedCompYearly'].min()
# Out:
# 1250000.0

# %%
emp_data = data[data['Employment'] == 'Employed']

# %%
emp_data['ConvertedCompYearly'].min()
# Out:
# nan

# %%
import numpy as np
emp_data = data[(data['Employment'] == 'Employed') & data['ConvertedCompYearly']!=np.nan]

# %%
emp_data['ConvertedCompYearly'].min()
# Out:
# 1250000.0

# %%
american_devs = data[data['Country']=="United States of America"]
american_devs
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 771         I agree                     I am a developer by profession
# 5905        I agree                     I am a developer by profession
# 7487        I agree                     I am a developer by profession
# 9394        I agree                     I am a developer by profession
# 16667       I agree                     I am a developer by profession
# 25652       I agree                     I am a developer by profession
# 27595       I agree  I am not primarily a developer, but I write co...
# 32150       I agree                     I am a developer by profession
# 35008       I agree                     I am a developer by profession
# 49784       I agree                     I am a developer by profession
# 51183       I agree                     I am a developer by profession
# 51715       I agree  I am not primarily a developer, but I write co...
# ...

# %%
max_american_salary = american_devs['ConvertedCompYearly'].max()

# %%
american_devs[american_devs['ConvertedCompYearly'] == max_american_salary]
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 80587       I agree  I am a developer by profession  18-24 years old
#
#                                                    Employment  \
# ResponseId
# 80587       Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 80587       Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 80587       Hobby;Contribute to open-source projects;Boots...
#
#                                                  EdLevel  \
# ResponseId
# 80587       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 80587       Hackathons (virtual or in-person);Other online...
#
#                                               LearnCodeOnline  \
# ResponseId
# 80587       Formal documentation provided by the owner of ...
#
# ...

# %%
min_american_salary = american_devs['ConvertedCompYearly'].min()

# %%
min_american_salary
# Out:
# 1250000.0

# %%
american_devs['ConvertedCompYearly'].mean()
# Out:
# 3125495.6875

# %%
american_devs[american_devs['YearsCodePro']==2]['ConvertedCompYearly'].mean()
# Out:
# 9000000.0

# %%
american_devs[american_devs['YearsCodePro']==2]['ConvertedCompYearly'].max()
# Out:
# 9000000.0

# %%
american_devs[american_devs['YearsCodePro']==2]['ConvertedCompYearly'].min()
# Out:
# 9000000.0

# %%
data[data['LanguageHaveWorkedWith'] == 'JavaScript']['ConvertedCompYearly'].mean()
# Out:
# 1365520.0

# %%
data['ConvertedCompYearly'].sum()
# Out:
# 480757277.0

# %%
data.groupby('Country').sum()['ConvertedCompYearly'].sort_values(ascending=False)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10980\947026942.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Country').sum()['ConvertedCompYearly'].sort_values(ascending=False)
# Country
# Australia                                               82629877.0
# Canada                                                  81786575.0
# South Africa                                            73607918.0
# Thailand                                                60389523.0
# United States of America                                50007931.0
# Mali                                                    36573181.0
# Ethiopia                                                17612921.0
# Brazil                                                  14148048.0
# ...

# %%
data.groupby('RemoteWork').sum()['ConvertedCompYearly'].sort_values(ascending=False)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10980\3932191614.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('RemoteWork').sum()['ConvertedCompYearly'].sort_values(ascending=False)
# RemoteWork
# Hybrid (some remote, some in-person)    210788310.0
# Remote                                  166377981.0
# In-person                                22105137.0
# Name: ConvertedCompYearly, dtype: float64

# %%
data['RemoteWork'].value_counts()
# Out:
# Remote                                  21
# Hybrid (some remote, some in-person)    18
# In-person                                6
# Name: RemoteWork, dtype: int64

# %%
data['EdLevel'].value_counts(normalize=True) * 100
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          43.750000
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                        20.833333
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       16.666667
# Some college/university study without earning a degree                                 6.250000
# Associate degree (A.A., A.S., etc.)                                                    6.250000
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4.166667
# Primary/elementary school                                                              2.083333
# Name: EdLevel, dtype: float64

# %%
from matplotlib import pyplot as plt
percent_spread = data['EdLevel'].value_counts(normalize=True) * 100

# %%
percent_spread = percent_spread.sort_values()

# %%
percent_spread.plot(kind='barh')
plt.title('Distribution of education level')
plt.xlabel('Percentage')
plt.ylabel('Education Level')
plt.show()

# %%
data['LearnCode'].value_counts()
# Out:
# Other online resources (e.g., videos, blogs, forum)                                                                                                                                                                                                                                   6
# Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)                                                                                                                                                                                           4
# Books / Physical media;Online Courses or Certification;Other online resources (e.g., videos, blogs, forum)                                                                                                                                                                            3
# ...

# %%
data['LearnCode'].str.split(";")
# Out:
# ResponseId
# 771      [Other online resources (e.g., videos, blogs, ...
# 5905                             [Other (please specify):]
# 7487     [Books / Physical media, Online Courses or Cer...
# 7995     [Books / Physical media, Online Courses or Cer...
# 9394     [Other online resources (e.g., videos, blogs, ...
# 10519                            [Friend or family member]
# 14592    [Books / Physical media, Other online resource...
# 16082    [Books / Physical media, Colleague, Hackathons...
# 16632    [Other online resources (e.g., videos, blogs, ...
# 16667    [Books / Physical media, Other online resource...
# 19680                            [Other (please specify):]
# 20783                    [Online Courses or Certification]
# 25205    [Other online resources (e.g., videos, blogs, ...
# 25652    [Other online resources (e.g., videos, blogs, ...
# 27595    [Books / Physical media, Colleague, Hackathons...
# 28122    [Books / Physical media, Other online resource...
# ...

# %%
data['LearnCode'].str.split(";").explode()
# Out:
# ResponseId
# 771      Other online resources (e.g., videos, blogs, f...
# 771                School (i.e., University, College, etc)
# 5905                               Other (please specify):
# 7487                                Books / Physical media
# 7487                       Online Courses or Certification
#                                ...
# 88348              School (i.e., University, College, etc)
# 88904                               Books / Physical media
# 88904                                  On the job training
# 88904    Other online resources (e.g., videos, blogs, f...
# 88904              School (i.e., University, College, etc)
# Name: LearnCode, Length: 151, dtype: object

# %%
learn_methods = data['LearnCode'].str.split(";").explode()

# %%
learn_methods.value_counts()
# Out:
# Other online resources (e.g., videos, blogs, forum)    34
# Books / Physical media                                 25
# School (i.e., University, College, etc)                23
# Online Courses or Certification                        20
# On the job training                                    12
# Other (please specify):                                 8
# Hackathons (virtual or in-person)                       8
# Coding Bootcamp                                         8
# Colleague                                               7
# Friend or family member                                 6
# Name: LearnCode, dtype: int64

# %%
learn_methods.value_counts(normalize=True) * 100
# Out:
# Other online resources (e.g., videos, blogs, forum)    22.516556
# Books / Physical media                                 16.556291
# School (i.e., University, College, etc)                15.231788
# Online Courses or Certification                        13.245033
# On the job training                                     7.947020
# Other (please specify):                                 5.298013
# Hackathons (virtual or in-person)                       5.298013
# Coding Bootcamp                                         5.298013
# Colleague                                               4.635762
# Friend or family member                                 3.973510
# Name: LearnCode, dtype: float64

# %%
method_counts = learn_methods.value_counts()
method_counts
# Out:
# Other online resources (e.g., videos, blogs, forum)    34
# Books / Physical media                                 25
# School (i.e., University, College, etc)                23
# Online Courses or Certification                        20
# On the job training                                    12
# Other (please specify):                                 8
# Hackathons (virtual or in-person)                       8
# Coding Bootcamp                                         8
# Colleague                                               7
# Friend or family member                                 6
# Name: LearnCode, dtype: int64

# %%
method_percentages = (method_counts / 88904) * 100

# %%
method_percentages
# Out:
# Other online resources (e.g., videos, blogs, forum)    0.038243
# Books / Physical media                                 0.028120
# School (i.e., University, College, etc)                0.025871
# Online Courses or Certification                        0.022496
# On the job training                                    0.013498
# Other (please specify):                                0.008998
# Hackathons (virtual or in-person)                      0.008998
# Coding Bootcamp                                        0.008998
# Colleague                                              0.007874
# Friend or family member                                0.006749
# Name: LearnCode, dtype: float64

# %%
from matplotlib import pyplot as plt
method_percentages = method_percentages.sort_values()
method_percentages.plot(kind='barh')
plt.title('Learning Methods')
plt.xlabel('Percentage')
plt.ylabel('Learn Code')
for index,value in enumerate(method_percentages):
    plt.text(value,index,f'{value:.2f}%',va='center')
plt.show()

# %%
online_learning_methods=data['LearnCodeOnline'].str.split(';').explode()

# %%
online_method_counts=online_learning_methods.value_counts()
online_method_percentages = (online_method_counts/89184)*100

# %%
online_method_percentages
# Out:
# Stack Overflow                                                 0.033638
# Formal documentation provided by the owner of the tech         0.032517
# Blogs with tips and tricks                                     0.028032
# How-to videos                                                  0.028032
# Written Tutorials                                              0.022426
# Click to write Choice 20                                       0.021304
# Video-based Online Courses                                     0.020183
# Written-based Online Courses                                   0.017940
# Books                                                          0.016819
# Recorded coding sessions                                       0.015698
# Online challenges (e.g., daily or weekly coding challenges)    0.014577
# Interactive tutorial                                           0.010091
# Certification videos                                           0.007849
# ...

# %%
from matplotlib import pyplot as plt
online_method_percentages = online_method_percentages.sort_values()
online_method_percentages.plot(kind='barh')
plt.title('Online Learning Methods')
plt.xlabel('Percentage')
plt.ylabel('Learn Code Online')
for index,value in enumerate(online_method_percentages):
    plt.text(value,index,f'{value:.2f}%',va='center')
plt.show()

# %%
data
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 771         I agree                     I am a developer by profession
# 5905        I agree                     I am a developer by profession
# 7487        I agree                     I am a developer by profession
# 7995        I agree                     I am a developer by profession
# 9394        I agree                     I am a developer by profession
# 10519       I agree                     I am a developer by profession
# 14592       I agree                     I am a developer by profession
# 16082       I agree                     I am a developer by profession
# 16632       I agree                     I am a developer by profession
# 16667       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 20783       I agree                     I am a developer by profession
# ...

# %%
online_platform_responses = data[data['LearnCodeCoursesCert']!=np.nan]

# %%
online_platform_responses
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 771         I agree                     I am a developer by profession
# 5905        I agree                     I am a developer by profession
# 7487        I agree                     I am a developer by profession
# 7995        I agree                     I am a developer by profession
# 9394        I agree                     I am a developer by profession
# 10519       I agree                     I am a developer by profession
# 14592       I agree                     I am a developer by profession
# 16082       I agree                     I am a developer by profession
# 16632       I agree                     I am a developer by profession
# 16667       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 20783       I agree                     I am a developer by profession
# ...

# %%
response_count = online_platform_responses.count()

# %%
response_count
# Out:
# Q120                   48
# MainBranch             48
# Age                    48
# Employment             48
# RemoteWork             45
#                        ..
# ProfessionalTech       26
# Industry               19
# SurveyLength           48
# SurveyEase             48
# ConvertedCompYearly    48
# Length: 83, dtype: int64

# %%
response_count_learncode = online_platform_responses['LearnCodeCoursesCert'].count()

# %%
response_count_learncode
# Out:
# 19

# %%
online_platform = data['LearnCodeCoursesCert'].str.split(';').explode()

# %%
online_platform_counts = online_platform.value_counts()
online_platform_counts
# Out:
# Udemy          10
# Coursera        9
# Other           7
# Codecademy      7
# edX             5
# Pluralsight     5
# Skillsoft       5
# Udacity         5
# Name: LearnCodeCoursesCert, dtype: int64

# %%
online_platform_percentages = (online_platform_counts/response_count_learncode) * 100

# %%
online_platform_percentages
# Out:
# Udemy          52.631579
# Coursera       47.368421
# Other          36.842105
# Codecademy     36.842105
# edX            26.315789
# Pluralsight    26.315789
# Skillsoft      26.315789
# Udacity        26.315789
# Name: LearnCodeCoursesCert, dtype: float64

# %%
from matplotlib import pyplot as plt
online_platform_percentages = online_platform_percentages.sort_values()
online_platform_percentages.plot(kind='barh')
plt.title('Online Platforms')
plt.xlabel('Percentage')
plt.ylabel('Learn Code Online Platforms')
for index,value in enumerate(online_platform_percentages):
    plt.text(value,index,f'{value:.2f}%',va='center')
plt.show()
